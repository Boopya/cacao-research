# %%
efficientNetB0 = {
    'loss' : [0.4248, 0.2864, 0.2321, 0.2357, 0.2202, 0.2264, 0.2157, 0.2172, 0.2033],
    'accuracy': [0.8140, 0.8865, 0.9099, 0.9090, 0.9214, 0.9236, 0.9205, 0.9258, 0.9271],
    'val_loss': [0.2743, 0.2719, 0.2671, 0.2812, 0.2605, 0.2607, 0.2866, 0.2819, 0.2875],
    'val_accuracy': [0.8938, 0.8920, 0.8956, 0.8903, 0.9062, 0.9133, 0.9080, 0.9062, 0.9097]
}

efficientNetV2B0 = {
    'loss': [0.4580, 0.3153, 0.2861, 0.2752, 0.2462, 0.2518, 0.2452, 0.2185, 0.2200, 0.2359],
    'accuracy': [0.8061, 0.8723, 0.8852, 0.8975, 0.9081, 0.9099, 0.9095, 0.9214, 0.9205, 0.9183],
    'val_loss': [0.3074, 0.3044, 0.2498, 0.2619, 0.2861, 0.2417, 0.2531, 0.2539, 0.2435, 0.2942],
    'val_accuracy': [0.8619, 0.88920, 0.9080, 0.8973, 0.9062, 0.9080, 0.9168, 0.9150, 0.9133, 0.9044]
}

resNet50 = {
    'loss': [0.7465, 0.4720, 0.3964, 0.3567, 0.3225, 0.3246, 0.2950, 0.2777, 0.2653],
    'accuracy': [0.7010, 0.8145, 0.8361, 0.8578, 0.8701, 0.8719, 0.8922, 0.8887, 0.8931],
    'val_loss':[0.4718, 0.4041, 0.3858, 0.5101, 0.3821, 0.4861, 0.4088, 0.3879, 0.3995],
    'val_accuracy': [0.8124, 0.8354, 0.8425, 0.7982, 0.8407, 0.8283, 0.8389, 0.8478, 0.8496]
}

xception = {
    'loss': [0.6291, 0.4350, 0.3530, 0.3233, 0.2868, 0.2615, 0.2453, 0.2256, 0.2184, 0.2044, 0.1985, 0.1817, 0.1778, 0.1695, 0.1617, 0.1564, 0.1420, 0.1457, 0.1342, 0.1259],
    'accuracy': [0.7352, 0.8263, 0.8678, 0.8771, 0.8952, 0.9032, 0.9098, 0.9222, 0.9195, 0.9319, 0.9319, 0.9368, 0.9385, 0.9412, 0.9408, 0.9483, 0.9540, 0.9492, 0.9536, 0.9642],
    'val_loss': [0.4860, 0.4165, 0.4768, 0.3950, 0.3735, 0.3663, 0.3798, 0.3729, 0.4276, 0.4203, 0.3677, 0.3803, 0.4311, 0.3645, 0.4108, 0.3900, 0.3837, 0.3851, 0.4396, 0.4027],
    'val_accuracy': [0.8020, 0.8350, 0.8055, 0.8328, 0.8555, 0.8532, 0.8430, 0.8567, 0.8203, 0.8237, 0.8510, 0.8441, 0.8248, 0.8567, 0.8294, 0.8464, 0.8476, 0.8430, 0.8282, 0.8453]
}

inceptionresnet = {
    'loss': [0.5865, 0.4683, 0.4392, 0.4194, 0.3785],
    'accuracy': [0.7795, 0.8268, 0.8265, 0.8436, 0.8573],
    'val_loss': [0.3947, 0.5396, 0.3507, 0.3507, 0.5715],
    'val_accuracy': [0.8453, 0.8043, 0.8703, 0.8680, 0.8294]
}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 8))

plt.plot(efficientNetB0['accuracy'], color="red")
plt.plot(efficientNetB0['val_accuracy'], color="blue")

plt.plot(efficientNetV2B0['accuracy'], color="yellow")
plt.plot(efficientNetV2B0['val_accuracy'], color="green")

plt.plot(resNet50['accuracy'], color="violet")
plt.plot(resNet50['val_accuracy'], color="pink")

plt.plot(xception['accuracy'], color="teal")
plt.plot(xception['val_accuracy'], color="brown")

plt.plot(inceptionresnet['accuracy'], color="teal")
plt.plot(inceptionresnet['val_accuracy'], color="brown")

plt.title('Model Accuracy')
plt.ylim(top=1.1)
plt.ylim(bottom=0)
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['efficientNetB0_train', 'efficientNetB0_val', 'efficientNetV2B0_train', 'efficientNetV2B0_val', 'resNet50_train', 'resNet50_val', 'xception_train', 'xception_val', 'inceptionresnet_train', 'inceptionresnet_val'], loc='lower left')

# %%
plt.figure(figsize=(20, 8))
plt.plot(efficientNetB0['loss'], color="red")
plt.plot(efficientNetB0['val_loss'], color="blue")


plt.plot(efficientNetV2B0['loss'], color="yellow")
plt.plot(efficientNetV2B0['val_loss'], color="green")

plt.plot(resNet50['loss'], color="violet")
plt.plot(resNet50['val_loss'], color="pink")

plt.plot(xception['loss'], color="violet")
plt.plot(xception['val_loss'], color="pink")

plt.plot(inceptionresnet['loss'], color="black")
plt.plot(inceptionresnet['val_loss'], color="silver")

plt.title('Model Loss')
plt.ylim(top=1.1)
plt.ylim(bottom=0)
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['efficientNetB0_train', 'efficientNetB0_val', 'efficientNetV2B0_train', 'efficientNetV2B0_val', 'resNet50_train', 'resNet50_val', 'xception_train', 'xception_val', 'inceptionresnet_train', 'inceptionresnet_val'], loc='upper right')

plt.show()
